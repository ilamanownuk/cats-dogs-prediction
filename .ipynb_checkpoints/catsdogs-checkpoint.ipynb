# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os

# %%
img = image.load_img("data/train/cats/cat.1.jpg")
plt.imshow(img)

# %%
train = ImageDataGenerator(rescale = 1/255)
validation = ImageDataGenerator(rescale=1/255)
train_set = train.flow_from_directory('data/train/',
                                     target_size=(200,200),
                                     batch_size=3,
                                     class_mode= 'binary')
validation_set = validation.flow_from_directory('data/validation/',
                                                target_size=(200,200),
                                                batch_size=3,
                                                class_mode= 'binary')
# Out:
# Found 8005 images belonging to 2 classes.
# Found 4001 images belonging to 2 classes.

# %%
train_set.class_indices
# Out:
# {'cats': 0, 'dogs': 1}

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3), activation='relu', input_shape= (200,200,3)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(32,(3,3), activation='relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(64,(3,3), activation='relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Flatten(),
                                    #
                                    tf.keras.layers.Dense(512,activation= 'relu'),
                                    #
                                    tf.keras.layers.Dense(1,activation= 'sigmoid')
                                   ])

# %%
model.compile(loss= 'binary_crossentropy',
             optimizer = RMSprop(lr=0.001),
             metrics=['accuracy'])

# %%
#model_fit = model.fit(train_set, steps_per_epoch=3, epochs=30,validation_data=validation_set)
model_fit = model.fit(train_set,validation_data=validation_set)
# Out:
# 2669/2669 [==============================] - 1421s 532ms/step - loss: 0.7142 - accuracy: 0.5890 - val_loss: 0.6556 - val_accuracy: 0.6733

# %%
dir_path = "data/test"
img = image.load_img(dir_path+'/cats/cat.4028.jpg', target_size=(200,200))
plt.imshow(img)
plt.show()
X = image.img_to_array(img)
X = np.expand_dims(X, axis=0)
images = np.vstack([X])
val = model.predict(images)
print(val)
if val == 0:
    print("Meow")
if val == 1:
    print("HawHaw")
# for i in os.listdir(dir_path):
#     img = image.load_img(dir_path+'//'+i, target_size=(200,200))
#     plt.imshow()
#     plt.show()
#     X = image.img_to_array(img)
#     X = np.expand_dims(X, axis=0)
#     images = np.vstack([X])
#     val = model.predict(images)
#     if val == 0:
#         print("Meow")
#     else:
#         print("HawHaw")
# Out:
# [[0.]]
# Meow
